# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\aksu\Downloads\amazon.csv\amazon.csv")

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df['category'].unique()
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables',
#        'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls',
#        'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables',
#        'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables',
#        'Electronics|HomeTheater,TV&Video|Projectors',
#        'Electronics|HomeAudio|Accessories|Adapters',
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
for i in df.columns:
    print(i, df[i].nunique())
# Out:
# product_id 1351
# product_name 1337
# category 211
# discounted_price 550
# actual_price 449
# discount_percentage 92
# rating 28
# rating_count 1143
# about_product 1293
# user_id 1194
# user_name 1194
# review_id 1194
# review_title 1194
# review_content 1212
# img_link 1412
# product_link 1465

# %%
for i in df.columns:
    print(i, df[i].duplicated().sum())
# Out:
# product_id 114
# product_name 128
# category 1254
# discounted_price 915
# actual_price 1016
# discount_percentage 1373
# rating 1437
# rating_count 321
# about_product 172
# user_id 271
# user_name 271
# review_id 271
# review_title 271
# review_content 253
# img_link 53
# product_link 0

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 3.0      3
# 4.8      3
# 5.0      3
# 2.8      2
# 3.2      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.dropna(inplace=True)

# %%
# Remove rupee symbol and convert to float
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(np.float64)
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(np.float64)
df['discount_percentage'] = df['discount_percentage'].str.replace('%', '').astype(np.float64)
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(np.int64)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['category'] = df['category'].str.split('|').str[0]
df['category'].unique()
# Out:
# array(['Computers&Accessories', 'Electronics', 'MusicalInstruments',
#        'OfficeProducts', 'Home&Kitchen', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'], dtype=object)

# %%
# top selling products based on discounted price

top_product = df.groupby('product_name').agg(sales = ("discounted_price" , "sum"),count_product = ("product_name", "count")).sort_values(by='sales', ascending=False).head(10).reset_index()
print(top_product)
# Out:
#                                         product_name    sales  count_product
# 0  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...  77990.0              1
# 1  OnePlus 163.8 cm (65 inches) U Series 4K LED S...  61999.0              1
# 2  VU 164 cm (65 inches) The GloLED Series 4K Sma...  54990.0              1
# 3  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...  47990.0              1
# 4  Samsung 138 cm (55 inches) Crystal 4K Neo Seri...  47990.0              1
# 5  MI 138.8 cm (55 inches) 5X Series 4K Ultra HD ...  46999.0              1
# 6  Samsung 138 cm (55 inches) Crystal 4K Series U...  45999.0              1
# 7  OnePlus 10T 5G (Moonstone Black, 8GB RAM, 128G...  44999.0              1
# 8  OnePlus 138.7 cm (55 inches) U Series 4K LED S...  42999.0              1
# 9  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...  42990.0              1

# %%
# top selling products 
top_selling_products = df['product_name'].value_counts().head(10)
print(top_selling_products)
# Out:
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                                            5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                                     4
# boAt Micro USB 55 Tangle-free, Sturdy Micro USB Cable with 3A Fast Charging & 480mbps Data Transmission (Black)                                                                                      3
# Duracell USB C To Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black                                      3
# ...

# %%
top_categories = df['category'].value_counts().head(10)
print(top_categories)
# Out:
# category
# Electronics              526
# Computers&Accessories    451
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
top_sales_categories = df.groupby('category')['discounted_price'].sum().sort_values(ascending=False).head(10)
print(top_sales_categories)
# Out:
# category
# Electronics              3138057.00
# Home&Kitchen             1044115.81
# Computers&Accessories     381272.62
# OfficeProducts              9349.00
# Car&Motorbike               2339.00
# MusicalInstruments          1276.00
# Health&PersonalCare          899.00
# HomeImprovement              674.00
# Toys&Games                   150.00
# Name: discounted_price, dtype: float64

# %%
dd = df.groupby('category').agg(count = ("discount_percentage","count"),sales=("discounted_price","sum")).sort_values(by ='count', ascending=False).reset_index(inplace=False)
dd['sales'] = dd['sales']/100000
plt.figure(figsize=(12,6))
sns.barplot(x = dd['category'], y = dd['sales'])
plt.xticks(rotation=45)
plt.xlabel('Category')
plt.ylabel('Total Sales in lakhs')
plt.title('Top Selling Categories by Sales')
plt.show()
plt.figure(figsize=(12,6))
sns.barplot(x = dd['category'], y = dd['count'])
plt.xticks(rotation=45)
plt.title('Top Selling Categories by Count')
plt.show()

# %%
df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df['discount_percentage'].unique()
# Out:
# array([64., 43., 90., 53., 61., 85., 65., 23., 50., 33., 55., 63., 69.,
#        60., 13., 44., 38., 39., 46., 41., 70., 42., 72., 25., 51., 73.,
#         0., 80., 28., 67., 58., 35., 45., 62., 54., 27., 77., 56., 78.,
#        31., 86., 47., 37., 75., 32., 68., 66., 22., 57., 17., 52., 88.,
#        20., 59., 40., 26., 29., 83., 71., 15., 76., 48., 82., 36., 89.,
#        87., 24., 34., 11., 91.,  7., 19., 79., 21., 81., 18., 49., 30.,
#        84., 10.,  6., 14., 74.,  4.,  5., 16.,  8.,  2., 94., 12.,  3.,
#         9.])

# %%
df.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#           category  discounted_price  actual_price  discount_percentage  \
# 1279  Home&Kitchen            2099.0        2499.0                 16.0
#
#      rating  rating_count                                      about_product  \
# 1279      |           992  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
# ...

# %%
df.drop(df[df['product_id'] == 'B08L12N5H1'].index, inplace=True)

# %%
df['rating'] = df['rating'].astype(np.float64)

# %%
df.groupby('category')['discount_percentage'].mean().sort_values(ascending=False)
# Out:
# category
# HomeImprovement          57.500000
# Computers&Accessories    53.920177
# Health&PersonalCare      53.000000
# Electronics              50.828897
# MusicalInstruments       46.000000
# Car&Motorbike            42.000000
# Home&Kitchen             40.174497
# OfficeProducts           12.354839
# Toys&Games                0.000000
# Name: discount_percentage, dtype: float64

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1462.000000    1462.000000          1462.000000  1462.000000
# mean        3129.981826    5453.087743            47.672367     4.096717
# std         6950.548042   10884.467444            21.613905     0.289497
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1670.000000            50.000000     4.100000
# 75%         1999.000000    4321.250000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1462.000000
# mean    18307.376881
# std     42766.096572
# min         2.000000
# 25%      1191.500000
# 50%      5179.000000
# 75%     17342.250000
# max    426973.000000

# %%
top_sales_ratings = df.groupby(['category', df['rating'].astype(int)])['discounted_price'].sum().sort_values(ascending=False)
print(top_sales_ratings)
# Out:
# category               rating
# Electronics            4         2810506.00
# Home&Kitchen           4          827367.34
# Electronics            3          327270.00
# Computers&Accessories  4          327000.88
# Home&Kitchen           3          211822.47
# Computers&Accessories  3           53373.74
# OfficeProducts         4            9349.00
# Home&Kitchen           2            2827.00
# Car&Motorbike          3            2339.00
# Health&PersonalCare    4             899.00
# Computers&Accessories  5             898.00
# MusicalInstruments     4             798.00
# HomeImprovement        4             674.00
# MusicalInstruments     3             478.00
# Electronics            2             281.00
# Toys&Games             4             150.00
# Name: discounted_price, dtype: float64

# %%
top_sales_on_rating = df.groupby("rating")["discounted_price"].sum().sort_values(ascending = False)
top_sales_on_rating
# Out:
# rating
# 4.3    1300610.10
# 4.1     886422.50
# 4.2     849260.06
# 4.0     369603.56
# 4.4     310896.00
# 3.9     307817.21
# 3.8     144942.00
# 4.5     112966.00
# 4.7      82385.00
# 4.6      57888.00
# 3.7      49698.00
# 3.6      30998.00
# 3.5      27824.00
# 3.4      16433.00
# 3.3      11832.00
# 4.8       6713.00
# 3.1       2468.00
# 3.0       2118.00
# 2.0       1299.00
# 3.2       1153.00
# 5.0        898.00
# 2.8        780.00
# 2.3        669.00
# 2.9        199.00
# 2.6        161.00
# Name: discounted_price, dtype: float64

# %%
sales_below_50_percent_discount = df[df['discount_percentage'] < 50].groupby('category')['discounted_price'].sum().sort_values(ascending=False)
print(sales_below_50_percent_discount)

print("-" * 50)

sales_above_50_percent_discount = df[df['discount_percentage'] > 50].groupby('category')['discounted_price'].sum().sort_values(ascending=False)
print(sales_above_50_percent_discount)
# Out:
# category
# Electronics              2622028.00
# Home&Kitchen              807960.81
# Computers&Accessories     238585.43
# OfficeProducts              7752.00
# Car&Motorbike               2339.00
# MusicalInstruments           478.00
# Toys&Games                   150.00
# Name: discounted_price, dtype: float64
# --------------------------------------------------
# category
# Electronics              485201.00
# Home&Kitchen             208574.00
# Computers&Accessories    129594.19
# OfficeProducts             1597.00
# Health&PersonalCare         899.00
# MusicalInstruments          798.00
# HomeImprovement             674.00
# Name: discounted_price, dtype: float64

# %%
plt.scatter(df['actual_price'], df['rating'].sort_values(ascending=True))
plt.xlabel('Actual_price')
plt.ylabel('Rating')
plt.show()

# %%
plt.scatter(df['discounted_price'], df['rating'])
plt.xlabel('Discounted_price')
plt.ylabel('Rating')
plt.show()

# %%
grouped_df = (df.groupby('category')['rating'].mean().reset_index().sort_values(by='rating', ascending=False).head(5))
grouped_df
# Out:
#                 category    rating
# 7         OfficeProducts  4.309677
# 8             Toys&Games  4.300000
# 5        HomeImprovement  4.250000
# 1  Computers&Accessories  4.155654
# 2            Electronics  4.081749

# %%
new_csv = df.to_csv(r"C:\Users\aksu\Downloads\amazon_cleaned.csv", index=False)
download_link = r"C:\Users\aksu\Downloads\amazon_cleaned.csv"
download_link
# Out:
# 'C:\\Users\\aksu\\Downloads\\amazon_cleaned.csv'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1462 non-null   object
#  1   product_name         1462 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1462 non-null   float64
#  4   actual_price         1462 non-null   float64
#  5   discount_percentage  1462 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1462 non-null   int64
#  8   about_product        1462 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1462 non-null   object
#  12  review_title         1462 non-null   object
#  13  review_content       1462 non-null   object
#  14  img_link             1462 non-null   object
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['product_id', 'product_name', 'category', 'user_id', 'user_name', 'review_id'], drop_first=True)
df_encoded.head()
# Out:
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                 64.0     4.2         24269
# 1             199.0         349.0                 43.0     4.0         43994
# 2             199.0        1899.0                 90.0     3.9          7928
# 3             329.0         699.0                 53.0     4.2         94363
# 4             154.0         399.0                 61.0     4.2         16905
#
#    about_product  review_title  review_content  img_link  product_link  ...  \
# 0            474           879             602      1116          1305  ...
# 1            279             7             411      1246           156  ...
# 2           1248           420             672       875          1157  ...
# 3           1009           374             268       517           379  ...
# 4           1187            44             120      1207           917  ...
#
# ...

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x = df[['actual_price'],['discount_percentage']]
y = df['discounted_price']

X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.30,random_state = 45)

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# linear regression model
from sklearn.linear_model import LinearRegression

regression = LinearRegression(n_jobs=-1)

regression.fit(X_train,Y_train)

print("coefficient or slope :",regression.coef_)
print("interception:",regression.intercept_)
# Out:
# coefficient or slope : [6141.52764513]
# interception: 2964.6480156402736

# %%
plt.scatter(X_train,Y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
y_pred = regression.predict(X_test)

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
score = r2_score(Y_test,y_pred)
mse = mean_absolute_error(Y_test,y_pred)
mae=mean_absolute_error(Y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
print(score)
# Out:
# 852.9187579276102
# 852.9187579276102
# 29.204772862112968
# 0.9431322986665688
